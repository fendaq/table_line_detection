# %%
import cv2
import numpy as np
from glob import glob
import matplotlib.pyplot as plt
def load_image(path, gray=False):
    '''
        return RGB or gray image
    '''
#     print(path, gray)
    if gray:
        return cv2.imread(path, 0)
    else:
        return cv2.cvtColor(cv2.imread(path), cv2.COLOR_BGR2RGB)

def write_image(path, image):
    print('write: {}, shape:{}'.format(path, image.shape))
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    return cv2.imwrite(path, image)
    
def show(x):
    plt.figure(figsize=(20, 20))
    plt.show(plt.imshow(x))

def normalize(im):
    _ = np.array(im<250, dtype='uint8')
    _ *= 255
    return _
    
paths = glob('data/train/*')
print('Num of big examples:', len(paths))
CROP_SIZE=512
# Out:
# Num of big examples: 3
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:962: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #2
#   (fname, cnt))
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py:962: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #3
#   (fname, cnt))

# %%
def split(img):
    w = img.shape[1]
    return img[:,:w//2], normalize(img[:,w//2:])

# %%
img = load_image(paths[0])
img = cv2.resize(img, (0,0), fx=.5, fy=.5)
a, b = split(img)

# %%
def random_crop(a, b):
    h,w = a.shape[:2]
    i1 = np.random.choice(h-CROP_SIZE)
    i2 = np.random.choice(w-CROP_SIZE)
    a_=  a[i1:i1+CROP_SIZE, i2:i2+CROP_SIZE]
    b_=  b[i1:i1+CROP_SIZE, i2:i2+CROP_SIZE]
    return np.concatenate([a_, b_], axis=1)

# %%
# !rm -r data/croped_image
# !mkdir data/croped_image

# %%
i = 0
for path in paths:
    bigimg = load_image(path)
    
    a,b = split(bigimg)
    for _ in tqdm(range(2000)):
        sample = random_crop(a, b)
        # plt.show(plt.imshow(sample))
        write_image('data/croped_image/{}.png'.format(i), sample)
        i += 1
# Out:
# write: data/croped_image/0.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/1.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/2.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/3.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/4.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/5.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/6.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/7.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/8.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/9.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/10.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/11.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/12.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/13.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/14.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/15.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/16.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/17.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/18.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/19.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/20.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/21.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/22.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/23.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/24.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/25.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/26.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/27.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/28.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/29.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/30.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/31.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/32.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/33.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/34.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/35.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/36.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/37.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/38.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/39.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/40.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/41.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/42.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/43.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/44.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/45.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/46.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/47.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/48.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/49.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/50.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/51.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/52.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/53.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/54.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/55.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/56.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/57.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/58.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/59.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/60.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/61.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/62.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/63.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/64.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/65.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/66.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/67.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/68.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/69.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/70.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/71.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/72.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/73.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/74.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/75.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/76.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/77.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/78.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/79.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/80.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/81.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/82.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/83.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/84.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/85.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/86.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/87.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/88.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/89.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/90.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/91.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/92.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/93.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/94.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/95.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/96.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/97.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/98.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/99.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/100.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/101.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/102.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/103.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/104.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/105.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/106.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/107.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/108.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/109.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/110.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/111.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/112.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/113.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/114.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/115.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/116.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/117.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/118.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/119.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/120.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/121.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/122.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/123.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/124.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/125.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/126.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/127.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/128.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/129.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/130.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/131.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/132.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/133.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/134.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/135.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/136.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/137.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/138.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/139.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/140.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/141.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/142.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/143.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/144.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/145.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/146.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/147.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/148.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/149.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/150.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/151.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/152.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/153.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/154.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/155.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/156.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/157.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/158.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/159.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/160.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/161.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/162.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/163.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/164.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/165.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/166.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/167.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/168.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/169.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/170.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/171.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/172.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/173.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/174.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/175.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/176.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/177.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/178.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/179.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/180.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/181.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/182.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/183.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/184.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/185.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/186.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/187.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/188.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/189.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/190.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/191.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/192.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/193.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/194.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/195.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/196.png, shape:(512, 1024, 3)
# True
# write: data/croped_image/197.png, shape:(512, 1024, 3)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-89726fa998f1> in <module>()
#       7         sample = random_crop(a, b)
#       8         # plt.show(plt.imshow(sample))
# ----> 9         print(write_image('data/croped_image/{}.png'.format(i), sample))
#      10         i += 1
#
# <ipython-input-1-a05ebd2515da> in write_image(path, image)
#      16     print('write: {}, shape:{}'.format(path, image.shape))
#      17     image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
# ---> 18     return cv2.imwrite(path, image)
#      19
#      20 def show(x):
#
# KeyboardInterrupt:

# %%
cv2.imwrite('test.png', )
# Out:
# True
